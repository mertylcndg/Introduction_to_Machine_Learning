# %% [markdown]
# <a href="https://colab.research.google.com/github/mertylcndg/Introduction_to_Machine_Learning_Assignments/blob/main/DTS_for_Beginner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Machine Learning Assignments Week 1 and Week2

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pokemon = pd.read_csv("/content/drive/MyDrive/Data/pokemon.csv")

# %%
data = pokemon.copy()

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 12 columns]

# %%
data.info() # basic informations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# # correlations map
# df.corr() == coraltions values

# %%
data.corr()
# Out:
#                    #        HP    Attack  ...     Speed  Generation  Legendary
# #           1.000000  0.097712  0.102664  ...  0.012181    0.983428   0.154336
# HP          0.097712  1.000000  0.422386  ...  0.175952    0.058683   0.273620
# Attack      0.102664  0.422386  1.000000  ...  0.381240    0.051451   0.345408
# Defense     0.094691  0.239622  0.438687  ...  0.015227    0.042419   0.246377
# Sp. Atk     0.089199  0.362380  0.396362  ...  0.473018    0.036437   0.448907
# Sp. Def     0.085596  0.378718  0.263990  ...  0.259133    0.028486   0.363937
# Speed       0.012181  0.175952  0.381240  ...  1.000000   -0.023121   0.326715
# Generation  0.983428  0.058683  0.051451  ... -0.023121    1.000000   0.079794
# Legendary   0.154336  0.273620  0.345408  ...  0.326715    0.079794   1.000000
#
# [9 rows x 9 columns]

# %%
f,ax = plt.subplots(figsize = (10,10))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt=".1f", ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#     #              Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0   1         Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1   2           Ivysaur  Grass  Poison  ...       80     60           1      False
# 2   3          Venusaur  Grass  Poison  ...      100     80           1      False
# 3   4     Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4   5        Charmander   Fire     NaN  ...       50     65           1      False
# 5   6        Charmeleon   Fire     NaN  ...       65     80           1      False
# 6   7         Charizard   Fire  Flying  ...       85    100           1      False
# 7   8  Mega Charizard X   Fire  Dragon  ...       85    100           1      False
# 8   9  Mega Charizard Y   Fire  Flying  ...      115    100           1      False
# 9  10          Squirtle  Water     NaN  ...       64     43           1      False
#
# [10 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 1. INTRODUCTION TO PYTHON
#
# ## MATPLOTLİB
# matplot is a python library that help us to plot data. The easiest and basic plot are line, scatter and histogram plots.
#
#  * Line plot is better when x axis is time
#  * Scatter is better when there is correlation between two variables
#  * Histogram is better when we need to see distribution of numerical data
#  * Customization: Color, label, thickness of line, title, opacity, grid, figsize, ticks of axis and linestyle

# %%
# Line Plot
# color = color,label = label, Linewidth = width of line, alpha = opacity, grid = grid, linestyle= style of line
data.Speed.plot(kind="line",color="g",label="Speed",linewidth = 1,alpha=0.5,grid=True,linestyle=":")
data.Defense.plot(color="r",label="Defense",linewidth=1,alpha=0.5,grid=True,linestyle="-.")
plt.legend(loc="upper right") # legend = puts label into plot
plt.xlabel("x axis")          # label = name of label
plt.ylabel("y axis")
plt.title("Line Plot")        # title = title of plot
plt.show()

# %%
# Scatter Plot
# x = attack, y = defense
data.plot(kind="scatter",x="Attack",y="Defense",alpha=0.5, color="red")
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Attack Defense Scatter Plot")
plt.show()

# %%
plt.scatter(data.Attack,data.Defense,color="red",alpha=0.5)
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Attack Defense Scatter Plot")
plt.show()

# %%
#Histogram
#bins = number of bar in figure
data.Speed.plot(kind="hist",bins= 50,figsize=(10,10))
plt.xlabel("Speed")
plt.show()

# %%
#clf() = cleans it up again you can start a fresh
data.Speed.plot(kind="hist",bins = 50)
plt.clf()
# we connot se plot due to clf()

# %% [markdown]
# # DICTIONARY
#
# Why we need dictionary
# * It has "key" and "value"
# * Faster than lists
#   What is key and value.Example:
# * dictionary = ("spain":"madrid")
# * Key is spain
# * Values is madrid

# %%
dictionary = {"spain": "madrid","usa":"vegas"}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
# Keys have to be immutable objects like string, boolean, float, integer or tuples
# List is not immutable
# Keys are unique
dictionary["spain"] = "barcelona"    # Update existing entry
print(dictionary)
dictionary["france"] = "paris"       # Add new entry
print(dictionary)
del dictionary["spain"]              # Remove enrty with key "spain"
print(dictionary)
print("france" in dictionary)        # Check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
# In ordet to run all code you need to take comment this line
# Del dictionary             # delete entrire dictionary

# %% [markdown]
# ## PANDAS
# What we need to know about pandas?
# * CSV:coma-separated values

# %%
data = pd.read_csv("/content/drive/MyDrive/Data/pokemon.csv")

# %%
series = data["Defense"]     # data["Defense"] = series
print(type(series))
data_frame = data[["Defense"]]  # data[["Defense"]] = data frame
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# 1- Filtering pandas data frame
x = data["Defense"]>200  # There are only 3 pokemons who have higher defense valur than 200
data[x]
# Out:
#        #          Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 224  225  Mega Steelix  Steel  Ground  ...       95     30           2      False
# 230  231       Shuckle    Bug    Rock  ...      230      5           2      False
# 333  334   Mega Aggron  Steel     NaN  ...       80     50           3      False
#
# [3 rows x 12 columns]

# %%
# 2- Filterimg pandas with ligical_and
# There are only 2 pokemons who have higher defence value than 200 and higher attack value than 100
data[np.logical_and(data["Defense"]>200,data["Attack"]>100)]
# Out:
#        #          Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 224  225  Mega Steelix  Steel  Ground  ...       95     30           2      False
# 333  334   Mega Aggron  Steel     NaN  ...       80     50           3      False
#
# [2 rows x 12 columns]

# %%
# This is also same whit previous code line. Therefore we can alsouse'&' for filtering
data[(data["Defense"]>200)&(data["Attack"]>100)]
# Out:
#        #          Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 224  225  Mega Steelix  Steel  Ground  ...       95     30           2      False
# 333  334   Mega Aggron  Steel     NaN  ...       80     50           3      False
#
# [2 rows x 12 columns]

# %% [markdown]
# ## While and For Loops
# We will learn most basic while and for loops

# %%
# Stay in loop if conditions(i is not equal 5) is true
i=0
while i !=5 : 
    print("i is: ",i)
    i+=1
print(i, " is equal to 5")
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %%
# Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]
for i in lis:
    print("i is: ",i)
print(" ")

# enumerate index and value of list
# index : value = 0:1,1:2, 2:3, 3:3, 4:5
for index, value in enumerate(lis):
    print(index," : ",value)
    
print(" ")

# For dictionaries 
# We can use for loop to achive key value of dictionary. We learnt key and value at dictionary part.
dictionary = {"spain":"madrid","france":"paris"}
for key,value in dictionary.items():
    print(key," : ",value)
    
print(" ")

# For pandas we can achive index and value
for index,value in data[["Attack"]][0:1].iterrows():
    print(index, " : ",value)
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# spain  :  madrid
# france  :  paris
#
# 0  :  Attack    49
# Name: 0, dtype: int64

# %% [markdown]
# In this part, you learn:
# * how to import csv file
# * plotting line,scatter and histogram
# * basic dictionary features
# * basic pandas features like filtering that is actually something always used and main for being data scientist
# * while and for loops

# %% [markdown]
# # 2. PYTHON DATA SCIENCE TOOLBOX¶

# %% [markdown]
# ## USER DEFINED FUNCTION
# What we need to know about functions:
# * docstrings:documentation for functions.Example:<br>
#     for f():<br>
#     """ This is docstring for documentation of function f """
# * tuble:sequence of immutable python objects.<br>
#   cant modify values<br>
#   tuble uses paranthesis like tuble = (1,2,3)<br>
#   unpack tuble into several variables like a,b,c = tuble

# %%
# example of what we learn above
def tuble_ex():
    """ return defined t tuble"""
    t = (1,2,3)
    return t
a,b,c = tuble_ex()
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# ### SCOPE
# What we need to know about scope:
# * global:define main body in scrript
# * local: defined in a function
# * built in scope: names in predefined built in scope module such as print, len

# %%
# guess print what
x= 2  # global
def f():
    x=3 # local
    return x
print(x)   # global variables
print(f())  # local variables
# Out:
# 2
# 3

# %%
# what if there is not local scope
x=5
def f():
    y = 2*x   # there is no local x
    return y
print(f())    # it uses global scope x
# Out:
# 10

# %%
# how can we learn what is built in scope
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %% [markdown]
# ### NESTED FUNCTION
# * function inside function.
# * there is a LEGB rule that is search local scope, enclosing function,global is scope,respectively

# %%
# nested functions
def square():
    """ return square of value"""
    def add ():
        """ add two local variable """
        x = 2
        y = 3 
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %% [markdown]
# ### DEFAULT and FLEXIBLE ARGUMENTS
# * default argument example:<br>
#   def f(a,b=1):
#       """ b = 1 is default argument """
# * Flexible argument example:<br>
#   def f(*args):
#       """ *args can be one ore more """
#
#   def(""kwargs):
#       """ **kwargs is a dictionary """

# %%
# default arguments
def f(a,b=1,c=2):
    y =a+b+c
    return y
print(f(5))
# what if we want to chance default arguments
print(f(5,4,3))
# Out:
# 8
# 12

# %%
# flexible arguments *args
def f(*args):
    for i in args:
        print(i)
        
        
f(1)
print("")
f(1,2,3,4)
#flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary """
    for key, value in kwargs.items():
        print(key," ",value)
        
f(country = "spain", capital = "madrid", population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# ### LAMBDA FUNCTION
# faster way of writing function

# %%
# lambda function
square = lambda x: x**2   # where x is name of argument
print(square(4))
tot = lambda x,y,z: x+y+z   # where x,y,z are names of arguments
print(tot(1,2,3))
# Out:
# 16
# 6

# %% [markdown]
# ### ANONYMOSU FUNCTİON
# like lambda functions bur it can take more than one arguments
# * map(func.seq): applise a function to all the items in a list

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %% [markdown]
# ### ITERATORS
# * iterable is an object that can return an iterator
# * iterable: an object with an associated iter() method<br>
#   example: list, strings and dictionarys
# * iterator: produces next value with next() method

# %%
# iteration example
name = "mert"
it = iter(name)
print(next(it))   # print next iteration
print(*it)        # print remaining iterations
# Out:
# m
# e r t

# %% [markdown]
# zip() zip lists

# %%
# zip example
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip)
print(un_list1)
print(un_list2)
print(type(un_list2))
print(type(list(un_list1)))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>
# <class 'list'>

# %% [markdown]
# ### LIST COMPREHENSİON
# we use list comprehension for data analysis often<br>
# list comprehension collapse for loops for building lists into a single line<br>
# EX: num1 = [1,2,3] and we want to make it num2 = [2,3,4]. This can be done with for loop. However it is unnecessarily
# long. We can make it one line code that is list comprehension.

# %%
# example of list comprehension
num1 = [1,2,3]
num2 = [i + 1 for i in num1]
print(num2)
# Out:
# [2, 3, 4]

# %%
# conditionals on iterable
num1 = [5,10,15]
num2 = [i**2 if i ==10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %%
# make one mor list comprehension example with pandas
threshold = sum(data.Speed)/len(data.Speed)
data["speed_level"] = ["higt" if i > threshold else "mid" if i==threshold else "low" for i in data.Speed]
data.loc[:10,["speed_level","Speed"]]
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         higt     80
# 3         higt     80
# 4          low     65
# 5         higt     80
# 6         higt    100
# 7         higt    100
# 8         higt    100
# 9          low     43
# 10         low     58

# %% [markdown]
# # 3. CLEANING DATA

# %% [markdown]
# ## DIAGNOSE DATA and CLEANING
# we need to diagnose and clean data bfore exploring<br>
# Uncleand data:
#
# * Column name inconsistency like upper_lower case later or space between words
# * missing data
# * different language

# %%
data = pd.read_csv("/content/drive/MyDrive/Data/pokemon.csv")
data.head()
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 12 columns]

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 795  796         Diancie     Rock  Fairy  ...      150     50           6       True
# 796  797    Mega Diancie     Rock  Fairy  ...      110    110           6       True
# 797  798  Hoopa Confined  Psychic  Ghost  ...      130     70           6       True
# 798  799   Hoopa Unbound  Psychic   Dark  ...      130     80           6       True
# 799  800       Volcanion     Fire  Water  ...       90     70           6       True
#
# [5 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
 data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ### EXPLOTARY DATA ANALYSIS (EDA)
# value_counts(): Frequency counts<br>
# outliers: the value that is considerably higher or lower from rest of the data
#
# * Lets say value at 75% is Q3 and value at 25% is Q1.
# * Outlier are smaller than Q1 -1.5(Q3-Q1) and bigger than Q3 + 1.5(Q3-Q1).<br>   (Q3-Q1) = IQR<br>
#   We will use describe() method.Describe method includes:
# * count: number of entries
# * mean: average or entries
# * std: standart deviation
# * min: minimum entry
# * 25%: first quantile
# * 50%: median or second quantile
# * 75%: third quantile
# * max: maximum entry <br>

# %%
print(data["Type 1"].value_counts(dropna = False)) # if thare are nan values thar also be count
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe().T  # ignore null entries
# Out:
#             count       mean         std   min     25%    50%     75%    max
# #           800.0  400.50000  231.084400   1.0  200.75  400.5  600.25  800.0
# HP          800.0   69.25875   25.534669   1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366   5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501   5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294  10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916  20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474   5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290   1.0    2.00    3.0    5.00    6.0

# %% [markdown]
# ### VISUAL EXPLORATORY DATA ANALYSIS
# * Box plots: visualize basic statistics like outliers. min/max or quantiles

# %%
# for example: compare attack of pokemons that are legendary or not
# Black line at top is max
# Blue line at top is 75%
# Red line is median
# Blue line at bottom is 25%
# Black line at bottom is min
data.boxplot(column= "Attack",by="Legendary")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ### TIDY DATA
# We tidy data with melt(). Describing melt is confısing. Therefore lets make example to understand it.

# %%
# Firstly I create new data from pokemons data to explain melt more easily.
data_new = data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 12 columns]

# %%
# lets melt
# id_vars = what we do not wish to melt
# vaşue_vars = what we want to melt
melted = pd.melt(frame = data_new, id_vars = "Name", value_vars = ["Attack","Defense"])
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %% [markdown]
# ### PIVOTING DATA
# Revers of melting

# %%
# index  is name
# I want to make that colums are variable
# Finally values in columns are value
melted.pivot(index = "Name", columns = "variable", values = "value")
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %% [markdown]
# ### CONCATENATING DATA
# We can concatenate two dataframe

# %%
# firstly lets create 2 data framen
data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1,data2],axis = 0, ignore_index = True) # axis = 0 : adds dataframe in row
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0    1       Bulbasaur    Grass  Poison  ...       65     45           1      False
# 1    2         Ivysaur    Grass  Poison  ...       80     60           1      False
# 2    3        Venusaur    Grass  Poison  ...      100     80           1      False
# 3    4   Mega Venusaur    Grass  Poison  ...      120     80           1      False
# 4    5      Charmander     Fire     NaN  ...       50     65           1      False
# 5  796         Diancie     Rock   Fairy  ...      150     50           6       True
# 6  797    Mega Diancie     Rock   Fairy  ...      110    110           6       True
# 7  798  Hoopa Confined  Psychic   Ghost  ...      130     70           6       True
# 8  799   Hoopa Unbound  Psychic    Dark  ...      130     80           6       True
# 9  800       Volcanion     Fire   Water  ...       90     70           6       True
#
# [10 rows x 12 columns]

# %%
data1 = data["Attack"].head()
data2 = data["Defense"].head()
conc_data_col = pd.concat([data1,data2],axis = 1) # axis = 1 : adds dataframens in column
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %% [markdown]
# ### DATA TYPES
# There are 5 basic data types: object(string), boolean, integer, float, categorical.<br>
# We can make conversion data types like from str to categorical or from int to float<br>
# Why is category important:
#
# * make dataframe smaller in memory
# * can be utilized for analysis especially for sklearn

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# Lets convert object(str) to categorical and int to float
data["Type 1"] = data["Type 1"].astype("category")
data["Speed"] = data["Speed"].astype("float")
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %% [markdown]
# ### MISSING DATA AND TESTİNG WITH ASSERT
# ıf we encounter with missing data, what we can do:
#
# * leave as it
# * drop them whit dropna()
# * fill missing value whit fillna()
# * fill missing values whit test statistics like mean <br>
#   Assert statement: chack that you can turn on or turn of when you are done with your testing of the program

# %%
# lets look at does pokemon data have nan value
#as you can see there are 800 entries. however Type 2 has 414 non_null object so it has 386 null onject
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
data["Type 2"].value_counts(dropna = False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data.dropna(inplace = True)

# %%
assert data["Type 2"].notnull().all()

# %% [markdown]
# # 4. PANDAS FOUNDATION

# %%
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
df["capital"] = ["Madrid","Paris"]
df
# Out:
#   country population capital
# 0   Spain         11  Madrid
# 1  France         12   Paris

# %%
df["income"] = 0
df
# Out:
#   country population capital  income
# 0   Spain         11  Madrid       0
# 1  France         12   Paris       0

# %% [markdown]
# ### ISUAL EXPLORATORY DATA ANALYSIS
#
# * Plot
# * Subplot
# * Histogram
#    * bins: number of bins
#    * range(tuble): min and max values of bins
#    * normed(boolean): normalize or not
#    * cumulative(boolean): compule cumulative distribution

# %%
# plotting all data
data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
# scatter 
data1.plot(kind ="scatter",x = "Attack",y="Defense")
plt.show()

# %%
#hist plot
data1.plot(kind="hist",y= "Defense",bins= 50,range=(0,250))
plt.show()

# %%
# histogram subplot with non cumulative and cumulative
fig, axes = plt.subplots(nrows = 2, ncols = 1)
data1.plot(kind = "hist",y = "Defense",bins = 50,range = (0,250),ax = axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range = (0,250),ax = axes[1], cumulative = True )
plt.show()

# %% [markdown]
# # STATISTICAL EXPLORATORY DATA ANALYSIS¶

# %%
data.describe().T
# Out:
#             count        mean         std   min     25%    50%     75%    max
# #           414.0  415.456522  235.907863   1.0  221.50  416.0  622.75  800.0
# HP          414.0   70.649758   22.896557   1.0   55.00   70.0   85.00  150.0
# Attack      414.0   83.173913   33.698473  10.0   59.25   80.0  103.00  190.0
# Defense     414.0   79.676329   32.593788  15.0   55.00   75.5  100.00  230.0
# Sp. Atk     414.0   77.048309   33.805061  10.0   50.00   70.0  100.00  180.0
# Sp. Def     414.0   75.565217   27.949961  20.0   55.00   75.0   94.75  230.0
# Speed       414.0   70.514493   28.521408   5.0   50.00   70.0   91.00  160.0
# Generation  414.0    3.410628    1.663010   1.0    2.00    3.0    5.00    6.0

# %% [markdown]
# ## INDEXING PANDAS TIME SERIES
#  * datetime = object
#  * parse_dates(boolean): Transform date to ISO 8601 (yyyy-mm-dd hh:mm:ss ) format

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) # As you can see date is string
# however we want it to be datetime object
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
# close warning
import warnings
warnings.filterwarnings("ignore")
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #           Name Type 1  ...  Speed  Generation  Legendary
# date                                 ...
# 1992-01-10  1      Bulbasaur  Grass  ...   45.0           1      False
# 1992-02-10  2        Ivysaur  Grass  ...   60.0           1      False
# 1992-03-10  3       Venusaur  Grass  ...   80.0           1      False
# 1993-03-15  4  Mega Venusaur  Grass  ...   80.0           1      False
# 1993-03-16  7      Charizard   Fire  ...  100.0           1      False
#
# [5 rows x 12 columns]

# %%
# Now we can select according to our date index
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# #                     7
# Name          Charizard
# Type 1             Fire
# Type 2           Flying
# HP                   78
# Attack               84
# Defense              78
# Sp. Atk             109
# Sp. Def              85
# Speed             100.0
# Generation            1
# Legendary         False
# Name: 1993-03-16 00:00:00, dtype: object
#             #           Name Type 1  ...  Speed  Generation  Legendary
# date                                 ...
# 1992-03-10  3       Venusaur  Grass  ...   80.0           1      False
# 1993-03-15  4  Mega Venusaur  Grass  ...   80.0           1      False
# 1993-03-16  7      Charizard   Fire  ...  100.0           1      False
#
# [3 rows x 12 columns]

# %% [markdown]
# ### RESAMPLING PANDAS TIME SERIES¶
# * Resampling: statistical method over different time intervals
#    * Needs string to specify frequency like "M" = month or "A" = year
# * Downsampling: reduce date time rows to slower frequency like from daily to weekly
# * Upsampling: increase date time rows to faster frequency like from daily to hourly
# * Interpolate: Interpolate values according to different methods like ‘linear’, ‘time’ or index’
#   * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html

# %%
# We will use data2 that we create at previous part
data2.resample("A").mean()
# Out:
#               #         HP     Attack  ...      Speed  Generation  Legendary
# date                                   ...
# 1992-12-31  2.0  61.666667  64.333333  ...  61.666667         1.0        0.0
# 1993-12-31  5.5  79.000000  92.000000  ...  90.000000         1.0        0.0
#
# [2 rows x 9 columns]

# %%
# Lets resample with month
data2.resample("M").mean()
# As you can see there are a lot of nan because data2 does not include all months
# Out:
#               #    HP  Attack  Defense  ...  Sp. Def  Speed  Generation  Legendary
# date                                    ...
# 1992-01-31  1.0  45.0    49.0     49.0  ...     65.0   45.0         1.0        0.0
# 1992-02-29  2.0  60.0    62.0     63.0  ...     80.0   60.0         1.0        0.0
# 1992-03-31  3.0  80.0    82.0     83.0  ...    100.0   80.0         1.0        0.0
# 1992-04-30  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# 1992-05-31  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# 1992-06-30  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# 1992-07-31  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# 1992-08-31  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# 1992-09-30  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# 1992-10-31  NaN   NaN     NaN      NaN  ...      NaN    NaN         NaN        NaN
# ...

# %%
# In real life (data is real. Not created from us like data2) we can solve this problem with interpolate
# We can interpolete from first value
data2.resample("M").mean().interpolate("linear")
# Out:
#                    #         HP     Attack  ...      Speed  Generation  Legendary
# date                                        ...
# 1992-01-31  1.000000  45.000000  49.000000  ...  45.000000         1.0        0.0
# 1992-02-29  2.000000  60.000000  62.000000  ...  60.000000         1.0        0.0
# 1992-03-31  3.000000  80.000000  82.000000  ...  80.000000         1.0        0.0
# 1992-04-30  3.208333  79.916667  82.833333  ...  80.833333         1.0        0.0
# 1992-05-31  3.416667  79.833333  83.666667  ...  81.666667         1.0        0.0
# 1992-06-30  3.625000  79.750000  84.500000  ...  82.500000         1.0        0.0
# 1992-07-31  3.833333  79.666667  85.333333  ...  83.333333         1.0        0.0
# 1992-08-31  4.041667  79.583333  86.166667  ...  84.166667         1.0        0.0
# 1992-09-30  4.250000  79.500000  87.000000  ...  85.000000         1.0        0.0
# 1992-10-31  4.458333  79.416667  87.833333  ...  85.833333         1.0        0.0
# ...

# %% [markdown]
# # MANIPULATING DATA FRAMES WITH PANDAS¶

# %% [markdown]
# ### INDEXING DATA FRAMES
# * Indexing using square brackets
# * Using column attribute and row label
# * Using loc accessor
# * Selecting only some columns

# %%
# read data
data = pd.read_csv("/content/drive/MyDrive/Data/pokemon.csv")
data= data.set_index("#")
data.head()
# Out:
#             Name Type 1  Type 2  HP  ...  Sp. Def  Speed  Generation  Legendary
# #                                    ...
# 1      Bulbasaur  Grass  Poison  45  ...       65     45           1      False
# 2        Ivysaur  Grass  Poison  60  ...       80     60           1      False
# 3       Venusaur  Grass  Poison  80  ...      100     80           1      False
# 4  Mega Venusaur  Grass  Poison  80  ...      120     80           1      False
# 5     Charmander   Fire     NaN  39  ...       50     65           1      False
#
# [5 rows x 11 columns]

# %%
# indexing using square brackets
data["HP"][1]
# Out:
# 45

# %%
# using loc accessor
data.loc[1,["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
# Selecting only some columns
data[["HP","Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 4    80     100
# 5    39      52
# ..   ..     ...
# 796  50     100
# 797  50     160
# 798  80     110
# 799  80     160
# 800  80     110
#
# [800 rows x 2 columns]

# %% [markdown]
# ### SLICING DATA FRAME¶
# * Difference between selecting columns
# * Series and data frames
# * Slicing and indexing series
# * Reverse slicing
# * From something to end

# %%
# Difference between selecting columns: series and dataframes
print(type(data["HP"]))     # series
print(type(data[["HP"]]))   # data frames
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Slicing and indexing series
data.loc[1:10,"HP":"Defense"]   # 10 and "Defense" are inclusive
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
# Reverse slicing 
data.loc[10:1:-1,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
# From something to end
data.loc[1:10,"Speed":]
# Out:
#     Speed  Generation  Legendary
# #
# 1      45           1      False
# 2      60           1      False
# 3      80           1      False
# 4      80           1      False
# 5      65           1      False
# 6      80           1      False
# 7     100           1      False
# 8     100           1      False
# 9     100           1      False
# 10     43           1      False

# %% [markdown]
# ###FILTERING DATA FRAMES¶
# Creating boolean series Combining filters Filtering column based others

# %%
# Creating boolean series
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  ...  Sp. Def  Speed  Generation  Legendary
# #                                 ...
# 122  Chansey  Normal    NaN  250  ...      105     50           1      False
# 262  Blissey  Normal    NaN  255  ...      135     55           2      False
#
# [2 rows x 11 columns]

# %%
# Combining filters
first_filter = data.HP > 150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2   HP  ...  Sp. Def  Speed  Generation  Legendary
# #                                   ...
# 122    Chansey  Normal    NaN  250  ...      105     50           1      False
# 262    Blissey  Normal    NaN  255  ...      135     55           2      False
# 352    Wailord   Water    NaN  170  ...       45     60           3      False
# 656  Alomomola   Water    NaN  165  ...       45     65           5      False
#
# [4 rows x 11 columns]

# %%
# Filtering column based others
data.HP[data.Speed<15]
# Out:
# #
# 231     20
# 360     45
# 487     50
# 496    135
# 659     44
# Name: HP, dtype: int64

# %% [markdown]
# ## TRANSFORMING DATA
# * Plain python functions
# * Lambda function: to apply arbitrary python function to every element
# * Defining column using other columns

# %%
# Plain python functions
def div(n):
    return n/2
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Or we can use lambda function
data.HP.apply(lambda n : n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Defining column using other columns
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  ...  Speed  Generation  Legendary  total_power
# #                                    ...
# 1      Bulbasaur  Grass  Poison  45  ...     45           1      False           98
# 2        Ivysaur  Grass  Poison  60  ...     60           1      False          125
# 3       Venusaur  Grass  Poison  80  ...     80           1      False          165
# 4  Mega Venusaur  Grass  Poison  80  ...     80           1      False          223
# 5     Charmander   Fire     NaN  39  ...     65           1      False           95
#
# [5 rows x 12 columns]

# %% [markdown]
# ### INDEX OBJECTS AND LABELED DATA
# index: sequence of label

# %%
# our index name is this:
print(data.index.name)
# Out:
# #

# %%
# lets change it
data.index.name = "index_name"
data.head()
# Out:
#                      Name Type 1  Type 2  ...  Generation  Legendary  total_power
# index_name                                ...
# 1               Bulbasaur  Grass  Poison  ...           1      False           98
# 2                 Ivysaur  Grass  Poison  ...           1      False          125
# 3                Venusaur  Grass  Poison  ...           1      False          165
# 4           Mega Venusaur  Grass  Poison  ...           1      False          223
# 5              Charmander   Fire     NaN  ...           1      False           95
#
# [5 rows x 12 columns]

# %%
# Overwrite index
# if we want to modify index we need to change all of them.
# first copy of our data to data3 then change index 
data3 = data.copy()
# lets make index start from 100. It is not remarkable change but it is just example
data3.index = range(100,900,1)
data3.head()
# Out:
#               Name Type 1  Type 2  ...  Generation  Legendary  total_power
# 100      Bulbasaur  Grass  Poison  ...           1      False           98
# 101        Ivysaur  Grass  Poison  ...           1      False          125
# 102       Venusaur  Grass  Poison  ...           1      False          165
# 103  Mega Venusaur  Grass  Poison  ...           1      False          223
# 104     Charmander   Fire     NaN  ...           1      False           95
#
# [5 rows x 12 columns]

# %% [markdown]
# ### HIERARCHICAL INDEXING
# * Setting indexing

# %%
# lets read data frame one more time to start from beginning
data = pd.read_csv("/content/drive/MyDrive/Data/pokemon.csv")
data.head()
# As you can see there is index. However we want to set one or more column to be index
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 12 columns]

# %%
# Setting index : type 1 is outer type 2 is inner index
data1 = data.set_index(["Type 1","Type 2"]) 
data1.head(100)
# data1.loc["Fire","Flying"] # howw to use indexes
# Out:
#                  #           Name   HP  ...  Speed  Generation  Legendary
# Type 1 Type 2                           ...
# Grass  Poison    1      Bulbasaur   45  ...     45           1      False
#        Poison    2        Ivysaur   60  ...     60           1      False
#        Poison    3       Venusaur   80  ...     80           1      False
#        Poison    4  Mega Venusaur   80  ...     80           1      False
# Fire   NaN       5     Charmander   39  ...     65           1      False
# ...            ...            ...  ...  ...    ...         ...        ...
# Poison NaN      96         Grimer   80  ...     25           1      False
#        NaN      97            Muk  105  ...     50           1      False
# Water  NaN      98       Shellder   30  ...     40           1      False
#        Ice      99       Cloyster   50  ...     70           1      False
# Ghost  Poison  100         Gastly   30  ...     80           1      False
#
# [100 rows x 10 columns]

# %% [markdown]
# ### PIVOTING DATA FRAMES
# * pivoting: reshape tool

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# pivoting
df.pivot(index="treatment",columns = "gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %% [markdown]
# ### STACKING and UNSTACKING DATAFRAME¶
# * deal with multi label indexes
# * level: position of unstacked index
# * swaplevel: change inner and outer level index position

# %%
df1 = df.set_index(["treatment","gender"])
df1
# lets unstack it
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
# level determines indexes
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
# change inner and outer level index position
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %% [markdown]
# ## CATEGORICALS AND GROUPBY

# %%
# We will use df
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# according to treatment take means of other features
df.groupby("treatment").mean()   # mean is aggregation / reduction method
# there are other methods like sum, std,max or min
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
# we can only choose one of the feature
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64
